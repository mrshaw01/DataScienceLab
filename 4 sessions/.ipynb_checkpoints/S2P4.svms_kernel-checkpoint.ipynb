# %%
import os
import numpy as np
from sklearn.svm import SVC

# %%
def load_data(data_path):
        def sparse_to_dense(sparse_r_d, vocab_size):
            r_d = [0.0 for _ in range(vocab_size)]
            indices_tfidfs = sparse_r_d.split()
            for index_tfidf in indices_tfidfs:
                index = int(index_tfidf.split(":")[0])
                tfidf = float(index_tfidf.split(":")[1])
                r_d[index] = tfidf
            return np.array(r_d)

        with open(data_path) as f:
            d_lines = f.read().splitlines()

        with open(os.getcwd()+"/20news-bydate/20news-full-words-idfs.txt") as f:
            vocab_size = len(f.read().splitlines())

        data = []
        labels = []
        for d in d_lines:
            features = d.split("<fff>")
            label, doc_id = int(features[0]), int(features[1])
            if label not in labels:
                print(f"Loading cluster {label}")
            r_d = sparse_to_dense(sparse_r_d=features[2], vocab_size=vocab_size)
            data.append(r_d)
            labels.append(label)
        return data, labels

# %%
def compute_accuracy(predicted_y, expected_y):
    matches = np.equal(predicted_y, expected_y)
    accuracy = np.sum(matches.astype(float)/len(expected_y))
    return accuracy

# %%
train_x, train_y = load_data(data_path = os.getcwd()+'/20news-bydate/20news-train-tf-idf.txt')
# Out:
# Loading cluster 0
# Loading cluster 1
# Loading cluster 2
# Loading cluster 3
# Loading cluster 4
# Loading cluster 5
# Loading cluster 6
# Loading cluster 7
# Loading cluster 8
# Loading cluster 9
# Loading cluster 10
# Loading cluster 11
# Loading cluster 12
# Loading cluster 13
# Loading cluster 14
# Loading cluster 15
# Loading cluster 16
# Loading cluster 17
# Loading cluster 18
# Loading cluster 19

# %%
classifier = SVC(C=50.0, kernel='rbf', gamma=0.1, tol=0.001, verbose=True)
classifier.fit(train_x, train_y)
# Out:
# [LibSVM]*.*
# optimization finished, #iter = 1058
# obj = -468.398826, rho = 0.376277
# nSV = 479, nBSV = 0
# *
# optimization finished, #iter = 903
# obj = -423.998880, rho = 0.298190
# nSV = 427, nBSV = 0
# *
# optimization finished, #iter = 985
# obj = -449.153832, rho = 0.333287
# nSV = 444, nBSV = 0
# *.*
# optimization finished, #iter = 1026
# obj = -437.926960, rho = 0.319179
# nSV = 467, nBSV = 0
# *
# optimization finished, #iter = 956
# obj = -431.171141, rho = 0.309016
# nSV = 436, nBSV = 0
# *.*
# optimization finished, #iter = 1065
# obj = -441.407510, rho = 0.389374
# nSV = 474, nBSV = 0
# *.*
# optimization finished, #iter = 1055
# obj = -469.844868, rho = 0.357639
# nSV = 469, nBSV = 0
# *.*
# optimization finished, #iter = 1074
# obj = -439.783387, rho = 0.266592
# nSV = 464, nBSV = 0
# *.*
# optimization finished, #iter = 1083
# obj = -441.250372, rho = 0.293804
# nSV = 453, nBSV = 0
# *
# optimization finished, #iter = 889
# obj = -384.480949, rho = 0.190969
# nSV = 384, nBSV = 0
# *
# optimization finished, #iter = 895
# obj = -410.311217, rho = 0.053300
# nSV = 401, nBSV = 0
# *.*
# optimization finished, #iter = 1201
# obj = -478.395810, rho = 0.455281
# nSV = 516, nBSV = 0
# *.*
# optimization finished, #iter = 1226
# obj = -503.036610, rho = 0.352370
# nSV = 494, nBSV = 0
# *
# optimization finished, #iter = 997
# obj = -464.991891, rho = 0.259185
# nSV = 437, nBSV = 0
# *.*
# optimization finished, #iter = 1333
# obj = -808.274218, rho = 0.329052
# nSV = 529, nBSV = 0
# *.*
# optimization finished, #iter = 1074
# obj = -477.413033, rho = 0.148427
# nSV = 433, nBSV = 0
# *
# optimization finished, #iter = 932
# obj = -451.553266, rho = 0.049952
# nSV = 398, nBSV = 0
# *.*
# optimization finished, #iter = 1120
# obj = -532.112938, rho = 0.192443
# nSV = 471, nBSV = 0
# .*
# optimization finished, #iter = 1418
# obj = -1066.196090, rho = 0.217063
# nSV = 510, nBSV = 0
# .*
# optimization finished, #iter = 1669
# obj = -1694.526479, rho = -0.087476
# nSV = 622, nBSV = 11
# .*
# optimization finished, #iter = 1756
# obj = -1489.418640, rho = -0.007303
# nSV = 652, nBSV = 4
# .*
# optimization finished, #iter = 1526
# obj = -1052.074563, rho = -0.068436
# nSV = 610, nBSV = 1
# .*
# optimization finished, #iter = 1627
# obj = -1356.031825, rho = -0.118901
# nSV = 616, nBSV = 1
# *.*
# optimization finished, #iter = 1398
# obj = -1026.233687, rho = 0.023800
# nSV = 603, nBSV = 1
# *.*
# optimization finished, #iter = 1392
# obj = -735.781695, rho = -0.060565
# nSV = 572, nBSV = 0
# *.*
# optimization finished, #iter = 1282
# obj = -664.614718, rho = -0.154237
# nSV = 539, nBSV = 0
# *.*
# optimization finished, #iter = 1235
# obj = -643.064569, rho = -0.107238
# nSV = 532, nBSV = 0
# *.*
# optimization finished, #iter = 1091
# obj = -615.720644, rho = -0.177346
# nSV = 482, nBSV = 1
# *.*
# optimization finished, #iter = 1210
# obj = -610.763557, rho = -0.409669
# nSV = 500, nBSV = 0
# .*
# optimization finished, #iter = 1594
# obj = -1168.366088, rho = 0.082374
# nSV = 637, nBSV = 1
# *.*
# optimization finished, #iter = 1472
# obj = -786.250346, rho = -0.099395
# nSV = 591, nBSV = 0
# *.*
# optimization finished, #iter = 1346
# obj = -735.464162, rho = -0.170468
# nSV = 560, nBSV = 0
# *.*
# optimization finished, #iter = 1075
# obj = -608.551257, rho = -0.225350
# nSV = 496, nBSV = 0
# *.*
# optimization finished, #iter = 1126
# obj = -576.782419, rho = -0.304154
# nSV = 500, nBSV = 1
# *.*
# optimization finished, #iter = 1053
# obj = -499.346265, rho = -0.284161
# nSV = 463, nBSV = 0
# *.*
# optimization finished, #iter = 1163
# obj = -566.668786, rho = -0.225771
# nSV = 509, nBSV = 0
# *.*
# optimization finished, #iter = 1114
# obj = -589.076906, rho = -0.215164
# nSV = 491, nBSV = 1
# .*
# optimization finished, #iter = 1868
# obj = -1641.986623, rho = 0.067728
# nSV = 640, nBSV = 3
# *.*
# optimization finished, #iter = 1457
# obj = -980.766657, rho = -0.022168
# nSV = 574, nBSV = 1
# .*
# optimization finished, #iter = 1581
# obj = -1213.010166, rho = -0.103115
# nSV = 619, nBSV = 2
# *.*
# optimization finished, #iter = 1328
# obj = -897.380786, rho = 0.070562
# nSV = 574, nBSV = 0
# *.*
# optimization finished, #iter = 1219
# obj = -675.275131, rho = 0.044176
# nSV = 532, nBSV = 0
# *.*
# optimization finished, #iter = 1195
# obj = -596.231555, rho = -0.059350
# nSV = 504, nBSV = 0
# *.*
# optimization finished, #iter = 1146
# obj = -595.130312, rho = 0.007169
# nSV = 487, nBSV = 0
# *
# optimization finished, #iter = 937
# obj = -581.455189, rho = -0.093531
# nSV = 427, nBSV = 1
# *.*
# optimization finished, #iter = 1059
# obj = -583.905423, rho = -0.316900
# nSV = 460, nBSV = 1
# .*
# optimization finished, #iter = 1479
# obj = -1029.846344, rho = 0.139358
# nSV = 596, nBSV = 2
# *.*
# optimization finished, #iter = 1213
# obj = -673.879996, rho = -0.007683
# nSV = 523, nBSV = 0
# *.*
# optimization finished, #iter = 1072
# obj = -602.195478, rho = -0.055795
# nSV = 486, nBSV = 0
# *
# optimization finished, #iter = 973
# obj = -549.728391, rho = -0.175286
# nSV = 458, nBSV = 0
# *.*
# optimization finished, #iter = 1018
# obj = -620.048061, rho = -0.216050
# nSV = 452, nBSV = 2
# *
# optimization finished, #iter = 958
# obj = -427.312439, rho = -0.213784
# nSV = 431, nBSV = 0
# *.*
# optimization finished, #iter = 1079
# obj = -520.934482, rho = -0.137134
# nSV = 469, nBSV = 0
# *
# optimization finished, #iter = 930
# obj = -550.768865, rho = -0.165461
# nSV = 429, nBSV = 1
# .*
# optimization finished, #iter = 1996
# obj = -1602.807401, rho = -0.120724
# nSV = 685, nBSV = 2
# *.*
# optimization finished, #iter = 1317
# obj = -971.914905, rho = -0.104622
# nSV = 554, nBSV = 2
# .*
# optimization finished, #iter = 1689
# obj = -1433.219298, rho = 0.062632
# nSV = 669, nBSV = 2
# *.*
# optimization finished, #iter = 1319
# obj = -760.963145, rho = 0.018546
# nSV = 567, nBSV = 0
# *.*
# optimization finished, #iter = 1259
# obj = -648.708683, rho = -0.094764
# nSV = 543, nBSV = 0
# *.*
# optimization finished, #iter = 1281
# obj = -628.848889, rho = -0.027005
# nSV = 522, nBSV = 0
# *.*
# optimization finished, #iter = 1051
# obj = -619.692380, rho = -0.134502
# nSV = 459, nBSV = 1
# *.*
# optimization finished, #iter = 1126
# obj = -584.385301, rho = -0.339157
# nSV = 496, nBSV = 0
# .*
# optimization finished, #iter = 1780
# obj = -1554.177484, rho = 0.067382
# nSV = 676, nBSV = 4
# *.*
# optimization finished, #iter = 1276
# obj = -739.225436, rho = -0.042886
# nSV = 552, nBSV = 0
# *.*
# optimization finished, #iter = 1205
# obj = -635.274505, rho = -0.102954
# nSV = 532, nBSV = 0
# *.*
# optimization finished, #iter = 1086
# obj = -560.713638, rho = -0.182518
# nSV = 487, nBSV = 0
# *.*
# optimization finished, #iter = 1066
# obj = -572.905805, rho = -0.238416
# nSV = 473, nBSV = 1
# *.*
# optimization finished, #iter = 1061
# obj = -462.326729, rho = -0.241743
# nSV = 464, nBSV = 0
# *.*
# optimization finished, #iter = 1196
# obj = -540.736229, rho = -0.177278
# nSV = 502, nBSV = 0
# *.*
# optimization finished, #iter = 1034
# obj = -578.540220, rho = -0.188967
# nSV = 474, nBSV = 1
# *.*
# optimization finished, #iter = 1288
# obj = -844.583159, rho = -0.005360
# nSV = 551, nBSV = 0
# .*
# optimization finished, #iter = 1612
# obj = -1121.770109, rho = 0.151810
# nSV = 636, nBSV = 0
# *.*
# optimization finished, #iter = 1382
# obj = -753.756558, rho = 0.056725
# nSV = 563, nBSV = 0
# *.*
# optimization finished, #iter = 1326
# obj = -664.793104, rho = -0.073688
# nSV = 540, nBSV = 0
# *.*
# optimization finished, #iter = 1218
# obj = -628.117017, rho = -0.009931
# nSV = 510, nBSV = 0
# *.*
# optimization finished, #iter = 1017
# obj = -581.883796, rho = -0.097161
# nSV = 451, nBSV = 0
# *.*
# optimization finished, #iter = 1060
# obj = -549.065104, rho = -0.315725
# nSV = 475, nBSV = 0
# .*
# optimization finished, #iter = 1741
# obj = -1189.757425, rho = 0.209454
# nSV = 641, nBSV = 0
# *.*
# optimization finished, #iter = 1312
# obj = -726.563328, rho = -0.016948
# nSV = 554, nBSV = 0
# *.*
# optimization finished, #iter = 1203
# obj = -657.324441, rho = -0.075438
# nSV = 511, nBSV = 0
# *.*
# optimization finished, #iter = 1086
# obj = -540.197327, rho = -0.149181
# nSV = 498, nBSV = 0
# *.*
# optimization finished, #iter = 1122
# obj = -535.415707, rho = -0.206862
# nSV = 475, nBSV = 0
# *.*
# optimization finished, #iter = 1044
# obj = -458.548678, rho = -0.230987
# nSV = 456, nBSV = 0
# *.*
# optimization finished, #iter = 1093
# obj = -549.592152, rho = -0.157878
# nSV = 491, nBSV = 0
# *.*
# optimization finished, #iter = 1084
# obj = -533.270202, rho = -0.170151
# nSV = 472, nBSV = 0
# *.*
# optimization finished, #iter = 1285
# obj = -746.748122, rho = 0.098939
# nSV = 571, nBSV = 0
# *.*
# optimization finished, #iter = 1278
# obj = -666.179291, rho = 0.039715
# nSV = 540, nBSV = 0
# *.*
# optimization finished, #iter = 1150
# obj = -610.722217, rho = -0.060749
# nSV = 498, nBSV = 0
# *.*
# optimization finished, #iter = 1120
# obj = -583.608066, rho = -0.007783
# nSV = 502, nBSV = 0
# *
# optimization finished, #iter = 943
# obj = -545.242429, rho = -0.095503
# nSV = 434, nBSV = 1
# *.*
# optimization finished, #iter = 1199
# obj = -570.381914, rho = -0.307522
# nSV = 490, nBSV = 0
# *.*
# optimization finished, #iter = 1484
# obj = -907.064080, rho = 0.153179
# nSV = 594, nBSV = 1
# *.*
# optimization finished, #iter = 1253
# obj = -695.303510, rho = -0.037586
# nSV = 542, nBSV = 0
# *.*
# optimization finished, #iter = 1209
# obj = -638.902027, rho = -0.088977
# nSV = 514, nBSV = 0
# *.*
# optimization finished, #iter = 1029
# obj = -531.665594, rho = -0.140909
# nSV = 469, nBSV = 0
# *
# optimization finished, #iter = 978
# obj = -518.280792, rho = -0.205820
# nSV = 454, nBSV = 1
# *
# optimization finished, #iter = 980
# obj = -442.403493, rho = -0.225928
# nSV = 431, nBSV = 0
# *.*
# optimization finished, #iter = 1087
# obj = -505.427947, rho = -0.159321
# nSV = 488, nBSV = 0
# *.*
# optimization finished, #iter = 999
# obj = -533.093333, rho = -0.159126
# nSV = 447, nBSV = 0
# *.*
# optimization finished, #iter = 1428
# obj = -1020.542808, rho = -0.050455
# nSV = 598, nBSV = 1
# *.*
# optimization finished, #iter = 1398
# obj = -789.614151, rho = -0.216599
# nSV = 587, nBSV = 0
# *.*
# optimization finished, #iter = 1299
# obj = -732.865963, rho = -0.120539
# nSV = 550, nBSV = 0
# *.*
# optimization finished, #iter = 1060
# obj = -679.834625, rho = -0.192010
# nSV = 485, nBSV = 0
# *.*
# optimization finished, #iter = 1061
# obj = -551.703085, rho = -0.402580
# nSV = 494, nBSV = 0
# .*
# optimization finished, #iter = 1626
# obj = -1442.375768, rho = 0.059053
# nSV = 660, nBSV = 4
# *.*
# optimization finished, #iter = 1318
# obj = -766.075118, rho = -0.124809
# nSV = 582, nBSV = 0
# *.*
# optimization finished, #iter = 1263
# obj = -687.445519, rho = -0.190137
# nSV = 542, nBSV = 0
# *.*
# optimization finished, #iter = 1024
# obj = -573.381230, rho = -0.225484
# nSV = 505, nBSV = 0
# *.*
# optimization finished, #iter = 1110
# obj = -571.621325, rho = -0.329071
# nSV = 500, nBSV = 0
# *.*
# optimization finished, #iter = 1050
# obj = -489.332892, rho = -0.319619
# nSV = 473, nBSV = 0
# *.*
# optimization finished, #iter = 1072
# obj = -629.898908, rho = -0.292774
# nSV = 507, nBSV = 0
# *.*
# optimization finished, #iter = 1021
# obj = -555.415861, rho = -0.260811
# nSV = 484, nBSV = 0
# .*
# optimization finished, #iter = 1502
# obj = -1032.962335, rho = -0.122638
# nSV = 568, nBSV = 2
# *.*
# optimization finished, #iter = 1259
# obj = -678.663842, rho = -0.050028
# nSV = 535, nBSV = 0
# *.*
# optimization finished, #iter = 1092
# obj = -556.840778, rho = -0.152370
# nSV = 476, nBSV = 0
# *.*
# optimization finished, #iter = 1130
# obj = -514.430773, rho = -0.308700
# nSV = 493, nBSV = 0
# .*
# optimization finished, #iter = 1608
# obj = -1010.128117, rho = 0.172784
# nSV = 643, nBSV = 0
# *.*
# optimization finished, #iter = 1406
# obj = -733.118103, rho = -0.040035
# nSV = 579, nBSV = 0
# *.*
# optimization finished, #iter = 1282
# obj = -635.812753, rho = -0.104939
# nSV = 537, nBSV = 0
# *.*
# optimization finished, #iter = 1122
# obj = -568.747619, rho = -0.171155
# nSV = 514, nBSV = 0
# *.*
# optimization finished, #iter = 1237
# obj = -619.425557, rho = -0.243387
# nSV = 500, nBSV = 0
# *.*
# optimization finished, #iter = 1104
# obj = -481.650425, rho = -0.270087
# nSV = 467, nBSV = 0
# *.*
# optimization finished, #iter = 1287
# obj = -638.994231, rho = -0.222567
# nSV = 532, nBSV = 0
# *.*
# optimization finished, #iter = 1099
# obj = -563.121716, rho = -0.201519
# nSV = 488, nBSV = 0
# *.*
# optimization finished, #iter = 1265
# obj = -608.382854, rho = 0.052590
# nSV = 513, nBSV = 0
# *.*
# optimization finished, #iter = 1088
# obj = -524.664008, rho = -0.046684
# nSV = 457, nBSV = 0
# *.*
# optimization finished, #iter = 1092
# obj = -487.022276, rho = -0.217286
# nSV = 465, nBSV = 0
# .*
# optimization finished, #iter = 1559
# obj = -752.640209, rho = 0.242310
# nSV = 617, nBSV = 0
# *.*
# optimization finished, #iter = 1419
# obj = -652.576899, rho = 0.065634
# nSV = 558, nBSV = 0
# *.*
# optimization finished, #iter = 1245
# obj = -585.776934, rho = -0.007234
# nSV = 516, nBSV = 0
# *.*
# optimization finished, #iter = 1111
# obj = -515.602120, rho = -0.074294
# nSV = 493, nBSV = 0
# *.*
# optimization finished, #iter = 1160
# obj = -559.669004, rho = -0.158877
# nSV = 468, nBSV = 0
# *.*
# optimization finished, #iter = 1023
# obj = -442.437268, rho = -0.185181
# nSV = 438, nBSV = 0
# *.*
# optimization finished, #iter = 1217
# obj = -573.766319, rho = -0.100087
# nSV = 495, nBSV = 0
# *.*
# optimization finished, #iter = 1179
# obj = -517.110596, rho = -0.107957
# nSV = 491, nBSV = 0
# .*
# optimization finished, #iter = 1503
# obj = -801.375547, rho = -0.143799
# nSV = 542, nBSV = 0
# *.*
# optimization finished, #iter = 1056
# obj = -469.577509, rho = -0.250921
# nSV = 449, nBSV = 0
# *.*
# optimization finished, #iter = 1456
# obj = -717.307136, rho = 0.151875
# nSV = 579, nBSV = 0
# *.*
# optimization finished, #iter = 1283
# obj = -657.305063, rho = 0.032774
# nSV = 519, nBSV = 0
# *.*
# optimization finished, #iter = 1288
# obj = -573.175039, rho = -0.055595
# nSV = 503, nBSV = 0
# *.*
# optimization finished, #iter = 1146
# obj = -531.648320, rho = -0.124545
# nSV = 490, nBSV = 0
# *.*
# optimization finished, #iter = 1243
# obj = -535.647121, rho = -0.202301
# nSV = 493, nBSV = 0
# *.*
# optimization finished, #iter = 1082
# obj = -456.760853, rho = -0.218705
# nSV = 449, nBSV = 0
# *.*
# optimization finished, #iter = 1159
# obj = -590.826228, rho = -0.150109
# nSV = 497, nBSV = 0
# *.*
# optimization finished, #iter = 1137
# obj = -519.423351, rho = -0.152573
# nSV = 467, nBSV = 0
# *
# optimization finished, #iter = 865
# obj = -401.891750, rho = -0.147951
# nSV = 391, nBSV = 0
# *.*
# optimization finished, #iter = 1299
# obj = -660.267499, rho = 0.225238
# nSV = 521, nBSV = 1
# *.*
# optimization finished, #iter = 1079
# obj = -543.932119, rho = 0.130544
# nSV = 474, nBSV = 0
# *.*
# optimization finished, #iter = 1040
# obj = -506.920780, rho = 0.048761
# nSV = 447, nBSV = 0
# *
# optimization finished, #iter = 914
# obj = -471.226276, rho = -0.047105
# nSV = 417, nBSV = 0
# *.*
# optimization finished, #iter = 1027
# obj = -507.691118, rho = -0.089533
# nSV = 422, nBSV = 2
# *
# optimization finished, #iter = 896
# obj = -415.521921, rho = -0.121730
# nSV = 387, nBSV = 0
# *
# optimization finished, #iter = 970
# obj = -496.852478, rho = -0.044405
# nSV = 436, nBSV = 0
# *
# optimization finished, #iter = 896
# obj = -495.505424, rho = -0.045778
# nSV = 402, nBSV = 2
# *.*
# optimization finished, #iter = 1348
# obj = -642.911954, rho = 0.467461
# nSV = 555, nBSV = 0
# *.*
# optimization finished, #iter = 1116
# obj = -568.770268, rho = 0.297834
# nSV = 483, nBSV = 0
# *.*
# optimization finished, #iter = 1047
# obj = -520.929815, rho = 0.222658
# nSV = 457, nBSV = 0
# *
# optimization finished, #iter = 976
# obj = -460.352397, rho = 0.148853
# nSV = 445, nBSV = 0
# *.*
# optimization finished, #iter = 1072
# obj = -605.372510, rho = 0.112943
# nSV = 449, nBSV = 0
# *
# optimization finished, #iter = 904
# obj = -414.981924, rho = 0.019796
# nSV = 400, nBSV = 0
# *.*
# optimization finished, #iter = 1182
# obj = -593.998966, rho = 0.180370
# nSV = 486, nBSV = 0
# *
# optimization finished, #iter = 903
# obj = -472.765316, rho = 0.112777
# nSV = 412, nBSV = 0
# *.*
# optimization finished, #iter = 1445
# obj = -922.299283, rho = -0.171681
# nSV = 598, nBSV = 0
# *.*
# optimization finished, #iter = 1507
# obj = -802.055813, rho = -0.260457
# nSV = 604, nBSV = 0
# *.*
# optimization finished, #iter = 1274
# obj = -635.039469, rho = -0.304261
# nSV = 552, nBSV = 0
# *.*
# optimization finished, #iter = 1365
# obj = -643.565689, rho = -0.358489
# nSV = 558, nBSV = 1
# *.*
# optimization finished, #iter = 1164
# obj = -509.461533, rho = -0.364789
# nSV = 496, nBSV = 0
# *.*
# optimization finished, #iter = 1355
# obj = -628.551056, rho = -0.333420
# nSV = 563, nBSV = 0
# *.*
# optimization finished, #iter = 1276
# obj = -616.598064, rho = -0.307566
# nSV = 525, nBSV = 1
# *.*
# optimization finished, #iter = 1298
# obj = -701.106108, rho = -0.072640
# nSV = 531, nBSV = 0
# *.*
# optimization finished, #iter = 1179
# obj = -644.780619, rho = -0.171303
# nSV = 520, nBSV = 0
# *.*
# optimization finished, #iter = 1260
# obj = -583.427056, rho = -0.250417
# nSV = 513, nBSV = 0
# *.*
# optimization finished, #iter = 1187
# obj = -481.919537, rho = -0.271771
# nSV = 488, nBSV = 0
# *.*
# optimization finished, #iter = 1330
# obj = -645.957159, rho = -0.195227
# nSV = 549, nBSV = 0
# *.*
# optimization finished, #iter = 1284
# obj = -601.797294, rho = -0.188102
# nSV = 517, nBSV = 0
# *.*
# optimization finished, #iter = 1144
# obj = -538.208656, rho = -0.058087
# nSV = 482, nBSV = 0
# *.*
# optimization finished, #iter = 1024
# obj = -591.958728, rho = -0.151265
# nSV = 442, nBSV = 1
# *.*
# optimization finished, #iter = 1035
# obj = -464.915909, rho = -0.174690
# nSV = 441, nBSV = 0
# *.*
# optimization finished, #iter = 1176
# obj = -597.857983, rho = -0.109629
# nSV = 478, nBSV = 0
# *.*
# optimization finished, #iter = 1023
# obj = -520.619920, rho = -0.089005
# nSV = 459, nBSV = 0
# *.*
# optimization finished, #iter = 1049
# obj = -528.223826, rho = -0.064810
# nSV = 459, nBSV = 0
# *.*
# optimization finished, #iter = 1011
# obj = -530.381429, rho = -0.160133
# nSV = 425, nBSV = 0
# *.*
# optimization finished, #iter = 1135
# obj = -603.477662, rho = -0.049080
# nSV = 497, nBSV = 0
# .*
# optimization finished, #iter = 1579
# obj = -1132.349551, rho = -0.119151
# nSV = 584, nBSV = 0
# *.*
# optimization finished, #iter = 1056
# obj = -478.708377, rho = -0.056421
# nSV = 436, nBSV = 0
# *.*
# optimization finished, #iter = 1369
# obj = -800.287767, rho = 0.080762
# nSV = 517, nBSV = 0
# *.*
# optimization finished, #iter = 1104
# obj = -659.192650, rho = 0.015553
# nSV = 455, nBSV = 1
# *.*
# optimization finished, #iter = 1095
# obj = -586.809003, rho = 0.126524
# nSV = 449, nBSV = 0
# *.*
# optimization finished, #iter = 996
# obj = -519.983692, rho = 0.124941
# nSV = 425, nBSV = 0
# *.*
# optimization finished, #iter = 1084
# obj = -684.651611, rho = -0.035057
# nSV = 460, nBSV = 0
# Total nSV = 8249
# SVC(C=50.0, gamma=0.1, verbose=True)

# %%
test_x, test_y = load_data(data_path = os.getcwd()+'/20news-bydate/20news-test-tf-idf.txt')
# Out:
# Loading cluster 0
# Loading cluster 1
# Loading cluster 2
# Loading cluster 3
# Loading cluster 4
# Loading cluster 5
# Loading cluster 6
# Loading cluster 7
# Loading cluster 8
# Loading cluster 9
# Loading cluster 10
# Loading cluster 11
# Loading cluster 12
# Loading cluster 13
# Loading cluster 14
# Loading cluster 15
# Loading cluster 16
# Loading cluster 17
# Loading cluster 18
# Loading cluster 19

# %%
predicted_y = classifier.predict(test_x)

# %%
accuracy = compute_accuracy(predicted_y = predicted_y, expected_y = test_y)
print("accuracy", accuracy)
# Out:
# accuracy 0.8247477429633562
