# %%
import os
import numpy as np
from os import listdir
from os.path import isfile
from collections import defaultdict
import re

# %%
def gather_20newsgroups_data():
    path = os.getcwd()+'/20news-bydate/'
    dirs = [(path + dir_name + '/')  for dir_name  in listdir(path) if not isfile(path + dir_name)]
    train_dir, test_dir = (dirs[0], dirs[1]) if 'train' in dirs[0] else (dirs[1], dirs[0])
    list_newgroups = [newsgroup for newsgroup in listdir(train_dir)]
    list_newgroups.sort()

    with open(os.getcwd()+'/stop-words.txt') as f:
        stop_words = f.read().splitlines()

    from nltk.stem.porter import PorterStemmer
    stemmer = PorterStemmer()

    def collect_data_from(parent_dir, newsgroup_list):
        data = []
        for group_id, newsgroup in enumerate(newsgroup_list):
            print(group_id, newsgroup)
            label = group_id
            dir_path = parent_dir + '/' + newsgroup + '/'
            files = [(filename, dir_path + filename) for filename in listdir(dir_path) if isfile(dir_path + filename)]
            files.sort()
            for filename, filepath in files:
                with open(filepath, encoding='latin1') as f:
                    text = str(f.read()).lower()
                    words = [stemmer.stem(word) for word in re.split('\W+', text) if word not in stop_words]
                    content = ' '.join(words)
                    assert len(content.splitlines()) == 1
                    data.append(str(label) + '<fff>' + filename + '<fff>' + content)
        print(len(data))
        return data
    
    train_data = collect_data_from(
        parent_dir = train_dir,
        newsgroup_list = list_newgroups
    )
    test_data = collect_data_from(
        parent_dir = test_dir,
        newsgroup_list = list_newgroups
    )
    full_data = train_data + test_data
    with open(os.getcwd()+'/20news-bydate/20news-train-processed.txt', 'w') as f:
        f.write('\n'.join(train_data))
    with open(os.getcwd()+'/20news-bydate/20news-test-processed.txt', 'w') as f:
        f.write('\n'.join(test_data))
    with open(os.getcwd()+'/20news-bydate/20news-full-processed.txt', 'w') as f:
        f.write('\n'.join(full_data))

gather_20newsgroups_data()
# Out:
# 0 alt.atheism
# 1 comp.graphics
# 2 comp.os.ms-windows.misc
# 3 comp.sys.ibm.pc.hardware
# 4 comp.sys.mac.hardware
# 5 comp.windows.x
# 6 misc.forsale
# 7 rec.autos
# 8 rec.motorcycles
# 9 rec.sport.baseball
# 10 rec.sport.hockey
# 11 sci.crypt
# 12 sci.electronics
# 13 sci.med
# 14 sci.space
# 15 soc.religion.christian
# 16 talk.politics.guns
# 17 talk.politics.mideast
# 18 talk.politics.misc
# 19 talk.religion.misc
# 11314
# 0 alt.atheism
# 1 comp.graphics
# 2 comp.os.ms-windows.misc
# 3 comp.sys.ibm.pc.hardware
# 4 comp.sys.mac.hardware
# 5 comp.windows.x
# 6 misc.forsale
# 7 rec.autos
# 8 rec.motorcycles
# 9 rec.sport.baseball
# 10 rec.sport.hockey
# 11 sci.crypt
# 12 sci.electronics
# 13 sci.med
# 14 sci.space
# 15 soc.religion.christian
# 16 talk.politics.guns
# 17 talk.politics.mideast
# 18 talk.politics.misc
# 19 talk.religion.misc
# 7532

# %%
def generate_vocabulary(data_path):
    def compute_idf(df, corpus_size):
        assert df > 0
        return np.log10(corpus_size*1./df)
    
    with open(data_path) as f:
        lines = f.read().splitlines()
    doc_count = defaultdict(int)
    corpus_size = len(lines)
    for line in lines:
        features = line.split('<fff>')
        text = features[-1]
        words = list(set(text.split()))
        for word in words:
            doc_count[word] += 1
    words_idfs = [(word, compute_idf(document_freq, corpus_size)) for word, document_freq in zip(doc_count.keys(), doc_count.values()) 
                    if document_freq > 10 and not word.isdigit()]
    words_idfs.sort(key = lambda word: -word[1])
    print('Vocabulary size: {}'.format(len(words_idfs)))
    with open(os.getcwd()+"/20news-bydate/20news-full-words-idfs.txt", "w") as f:
        f.write("\n".join([word + '<fff>' + str(idf) for word, idf in words_idfs]))

generate_vocabulary(os.getcwd()+"/20news-bydate/20news-full-processed.txt")
# Out:
# Vocabulary size: 14234

# %%
def get_tf_idf(data_path):
    with open(os.getcwd()+"/20news-bydate/20news-full-words-idfs.txt") as f:
        words_idfs = [(line.split('<fff>')[0], float(line.split('<fff>')[1])) for line in f.read().splitlines()]
        word_ids = dict([(word, index) for index, (word, idf) in enumerate(words_idfs)])
        idfs = dict(words_idfs)
    with open(data_path) as f:
        documents = [(int(line.split('<fff>')[0]),
                      int(line.split('<fff>')[1]),
                      line.split('<fff>')[2]) for line in f.read().splitlines()]
    data_tf_idf = []
    for document in documents:
        label, doc_id, text = document
        print("Processing document", doc_id)
        words = [word for word in text.split() if word in idfs]
        word_count = defaultdict(int)

        word_set = list(set(words))
        for word in words:
            word_count[word]+=1
        max_term_freq = max([word_count[word] for word in word_set])
        words_tfidfs = []
        sum_squares = 0.0
        for word in word_set:
            term_freq = word_count[word]
            tf_idf_value = term_freq * 1./ max_term_freq * idfs[word]
            words_tfidfs.append((word_ids[word], tf_idf_value))
            sum_squares += tf_idf_value**2
        words_tfidfs = sorted(words_tfidfs)
        words_tfidfs_normalized = [str(index) + ':' + str(tf_idf_value/np.sqrt(sum_squares)) for index, tf_idf_value in words_tfidfs]
        sparse_rep = ' '.join(words_tfidfs_normalized)
        data_tf_idf.append((label, doc_id, sparse_rep))
    data_tf_idf = sorted(data_tf_idf, key = lambda x: (x[0], x[1], x[2]))
    with open(os.getcwd()+"/20news-bydate/20news-full-tf-idf.txt","w") as f:
        f.write("\n".join([str(label) + '<fff>' + str(doc_id) + '<fff>' + sparse_rep for label, doc_id, sparse_rep in data_tf_idf]))

get_tf_idf(os.getcwd()+"/20news-bydate/20news-full-processed.txt")
# Out:
# Processing document 49960
# Processing document 51060
# Processing document 51119
# Processing document 51120
# Processing document 51121
# Processing document 51122
# Processing document 51123
# Processing document 51124
# Processing document 51125
# Processing document 51126
# Processing document 51127
# Processing document 51128
# Processing document 51130
# Processing document 51131
# Processing document 51132
# Processing document 51133
# Processing document 51134
# Processing document 51135
# Processing document 51136
# Processing document 51139
# Processing document 51140
# Processing document 51141
# Processing document 51142
# Processing document 51143
# Processing document 51144
# Processing document 51145
# Processing document 51146
# Processing document 51147
# Processing document 51148
# Processing document 51149
# Processing document 51150
# Processing document 51151
# Processing document 51152
# Processing document 51153
# Processing document 51154
# Processing document 51155
# Processing document 51156
# Processing document 51157
# Processing document 51158
# Processing document 51159
# Processing document 51160
# Processing document 51161
# Processing document 51162
# Processing document 51163
# Processing document 51164
# Processing document 51165
# Processing document 51169
# Processing document 51170
# Processing document 51171
# Processing document 51172
# Processing document 51173
# Processing document 51174
# Processing document 51175
# Processing document 51176
# Processing document 51177
# Processing document 51178
# Processing document 51179
# Processing document 51180
# Processing document 51181
# Processing document 51182
# Processing document 51183
# Processing document 51184
# Processing document 51185
# Processing document 51186
# Processing document 51187
# Processing document 51188
# Processing document 51189
# Processing document 51190
# Processing document 51191
# Processing document 51192
# Processing document 51193
# Processing document 51194
# Processing document 51195
# Processing document 51196
# Processing document 51197
# Processing document 51198
# Processing document 51199
# Processing document 51200
# Processing document 51201
# Processing document 51202
# Processing document 51203
# Processing document 51204
# Processing document 51205
# Processing document 51206
# Processing document 51208
# Processing document 51209
# Processing document 51210
# Processing document 51211
# Processing document 51212
# Processing document 51213
# Processing document 51214
# Processing document 51215
# Processing document 51216
# Processing document 51217
# Processing document 51218
# Processing document 51219
# Processing document 51220
# Processing document 51221
# Processing document 51222
# Processing document 51223
# Processing document 51224
# Processing document 51225
# Processing document 51226
# Processing document 51227
# Processing document 51228
# Processing document 51229
# Processing document 51230
# Processing document 51231
# Processing document 51232
# Processing document 51233
# Processing document 51234
# Processing document 51235
# Processing document 51236
# Processing document 51237
# Processing document 51238
# Processing document 51239
# Processing document 51240
# Processing document 51241
# Processing document 51242
# Processing document 51243
# Processing document 51244
# Processing document 51245
# Processing document 51246
# Processing document 51247
# Processing document 51249
# Processing document 51250
# Processing document 51251
# Processing document 51252
# Processing document 51253
# Processing document 51254
# Processing document 51255
# Processing document 51256
# Processing document 51258
# Processing document 51259
# Processing document 51260
# Processing document 51261
# Processing document 51262
# Processing document 51265
# Processing document 51266
# Processing document 51267
# Processing document 51268
# Processing document 51269
# Processing document 51270
# Processing document 51271
# Processing document 51272
# Processing document 51273
# Processing document 51274
# Processing document 51275
# Processing document 51276
# Processing document 51277
# Processing document 51278
# Processing document 51279
# Processing document 51280
# Processing document 51281
# Processing document 51282
# Processing document 51283
# Processing document 51284
# Processing document 51285
# Processing document 51286
# Processing document 51287
# Processing document 51288
# Processing document 51290
# Processing document 51291
# Processing document 51292
# Processing document 51293
# Processing document 51294
# Processing document 51295
# Processing document 51296
# Processing document 51297
# Processing document 51298
# Processing document 51299
# Processing document 51300
# Processing document 51301
# Processing document 51302
# Processing document 51303
# Processing document 51304
# Processing document 51305
# Processing document 51306
# Processing document 51307
# Processing document 51308
# Processing document 51309
# Processing document 51310
# Processing document 51311
# Processing document 51312
# Processing document 51313
# Processing document 51314
# Processing document 51315
# Processing document 51316
# Processing document 51317
# Processing document 51318
# Processing document 51319
# Processing document 51320
# Processing document 52499
# Processing document 52909
# Processing document 52910
# Processing document 53055
# Processing document 53056
# Processing document 53057
# Processing document 53058
# Processing document 53059
# Processing document 53062
# Processing document 53064
# Processing document 53065
# Processing document 53066
# Processing document 53067
# Processing document 53069
# Processing document 53070
# Processing document 53071
# Processing document 53072
# Processing document 53073
# Processing document 53075
# Processing document 53078
# Processing document 53081
# Processing document 53082
# Processing document 53083
# Processing document 53085
# Processing document 53086
# Processing document 53087
# Processing document 53090
# Processing document 53093
# Processing document 53094
# Processing document 53095
# Processing document 53096
# Processing document 53097
# Processing document 53098
# Processing document 53099
# Processing document 53106
# Processing document 53108
# Processing document 53110
# Processing document 53111
# Processing document 53112
# Processing document 53113
# Processing document 53114
# Processing document 53117
# Processing document 53118
# Processing document 53120
# Processing document 53121
# Processing document 53122
# Processing document 53123
# Processing document 53124
# Processing document 53125
# Processing document 53126
# Processing document 53127
# Processing document 53130
# Processing document 53131
# Processing document 53132
# Processing document 53133
# Processing document 53134
# Processing document 53135
# Processing document 53136
# Processing document 53137
# Processing document 53139
# Processing document 53140
# Processing document 53141
# Processing document 53142
# Processing document 53143
# Processing document 53144
# Processing document 53145
# Processing document 53149
# Processing document 53150
# Processing document 53151
# Processing document 53153
# Processing document 53154
# Processing document 53157
# Processing document 53158
# Processing document 53159
# Processing document 53160
# Processing document 53161
# Processing document 53162
# Processing document 53163
# Processing document 53164
# Processing document 53165
# Processing document 53166
# Processing document 53167
# Processing document 53168
# Processing document 53170
# Processing document 53171
# Processing document 53172
# Processing document 53173
# Processing document 53174
# Processing document 53175
# Processing document 53176
# Processing document 53177
# Processing document 53178
# Processing document 53179
# Processing document 53180
# Processing document 53181
# Processing document 53182
# Processing document 53183
# Processing document 53184
# Processing document 53185
# Processing document 53186
# Processing document 53187
# Processing document 53188
# Processing document 53190
# Processing document 53191
# Processing document 53192
# Processing document 53193
# Processing document 53194
# Processing document 53195
# Processing document 53196
# Processing document 53197
# Processing document 53198
# Processing document 53199
# Processing document 53201
# Processing document 53203
# Processing document 53208
# Processing document 53209
# Processing document 53210
# Processing document 53211
# Processing document 53212
# Processing document 53213
# Processing document 53214
# Processing document 53215
# Processing document 53216
# Processing document 53217
# Processing document 53218
# Processing document 53219
# Processing document 53220
# Processing document 53221
# Processing document 53222
# Processing document 53223
# Processing document 53224
# Processing document 53225
# Processing document 53226
# Processing document 53228
# Processing document 53229
# Processing document 53230
# Processing document 53231
# Processing document 53232
# Processing document 53235
# Processing document 53237
# Processing document 53238
# Processing document 53239
# Processing document 53240
# Processing document 53243
# Processing document 53248
# Processing document 53249
# Processing document 53250
# Processing document 53251
# Processing document 53252
# Processing document 53256
# Processing document 53258
# Processing document 53266
# Processing document 53267
# Processing document 53269
# Processing document 53271
# Processing document 53274
# Processing document 53275
# Processing document 53281
# Processing document 53282
# Processing document 53283
# Processing document 53284
# Processing document 53285
# Processing document 53286
# Processing document 53287
# Processing document 53288
# Processing document 53289
# Processing document 53290
# Processing document 53292
# Processing document 53298
# Processing document 53303
# Processing document 53304
# Processing document 53305
# Processing document 53306
# Processing document 53307
# Processing document 53308
# Processing document 53309
# Processing document 53311
# Processing document 53312
# Processing document 53314
# Processing document 53323
# Processing document 53334
# Processing document 53347
# Processing document 53351
# Processing document 53366
# Processing document 53370
# Processing document 53371
# Processing document 53373
# Processing document 53374
# Processing document 53375
# Processing document 53376
# Processing document 53377
# Processing document 53380
# Processing document 53381
# Processing document 53382
# Processing document 53383
# Processing document 53387
# Processing document 53389
# Processing document 53390
# Processing document 53391
# Processing document 53434
# Processing document 53435
# Processing document 53436
# Processing document 53437
# Processing document 53438
# Processing document 53439
# Processing document 53440
# Processing document 53441
# Processing document 53442
# Processing document 53443
# Processing document 53445
# Processing document 53449
# Processing document 53459
# Processing document 53460
# Processing document 53465
# Processing document 53466
# Processing document 53467
# Processing document 53468
# Processing document 53471
# Processing document 53477
# Processing document 53478
# Processing document 53483
# Processing document 53509
# Processing document 53510
# Processing document 53512
# Processing document 53515
# Processing document 53518
# Processing document 53519
# Processing document 53521
# Processing document 53522
# Processing document 53523
# Processing document 53524
# Processing document 53525
# Processing document 53526
# Processing document 53527
# Processing document 53528
# Processing document 53529
# Processing document 53531
# Processing document 53532
# Processing document 53533
# Processing document 53534
# Processing document 53535
# Processing document 53571
# Processing document 53572
# Processing document 53573
# Processing document 53574
# Processing document 53654
# Processing document 53655
# Processing document 53656
# Processing document 53660
# Processing document 53661
# Processing document 53753
# Processing document 53754
# Processing document 53755
# Processing document 53756
# Processing document 53757
# Processing document 53758
# Processing document 53759
# Processing document 53760
# Processing document 53761
# Processing document 53762
# Processing document 53763
# Processing document 53764
# Processing document 53765
# Processing document 53766
# Processing document 53780
# Processing document 53785
# Processing document 54165
# Processing document 54166
# Processing document 54167
# Processing document 54168
# Processing document 54178
# Processing document 54179
# Processing document 54180
# Processing document 54181
# Processing document 54182
# Processing document 54198
# Processing document 54199
# Processing document 54200
# Processing document 54201
# Processing document 54202
# Processing document 54203
# Processing document 54204
# Processing document 54227
# Processing document 54228
# Processing document 54470
# Processing document 54471
# Processing document 54472
# Processing document 54473
# Processing document 37261
# Processing document 37913
# Processing document 37914
# Processing document 37915
# Processing document 37916
# Processing document 37917
# Processing document 37918
# Processing document 37921
# Processing document 37922
# Processing document 37923
# Processing document 37924
# Processing document 37925
# Processing document 37926
# Processing document 37927
# Processing document 37928
# Processing document 37929
# Processing document 37930
# Processing document 37931
# Processing document 37932
# Processing document 37933
# Processing document 37934
# Processing document 37935
# Processing document 37936
# Processing document 37937
# Processing document 37938
# Processing document 37939
# Processing document 37940
# Processing document 37941
# Processing document 37942
# Processing document 37943
# Processing document 37944
# Processing document 37945
# Processing document 37946
# Processing document 37947
# Processing document 37948
# Processing document 37949
# Processing document 37950
# Processing document 37951
# Processing document 37952
# Processing document 37953
# Processing document 37954
# Processing document 37955
# Processing document 37956
# Processing document 37957
# Processing document 37958
# Processing document 37959
# Processing document 37960
# Processing document 37961
# Processing document 37962
# Processing document 37963
# Processing document 38099
# Processing document 38214
# Processing document 38215
# Processing document 38216
# Processing document 38217
# Processing document 38218
# Processing document 38219
# Processing document 38220
# Processing document 38221
# Processing document 38222
# Processing document 38223
# Processing document 38224
# Processing document 38225
# Processing document 38226
# Processing document 38227
# Processing document 38228
# Processing document 38229
# Processing document 38230
# Processing document 38231
# Processing document 38232
# Processing document 38233
# Processing document 38234
# Processing document 38235
# Processing document 38236
# Processing document 38237
# Processing document 38238
# Processing document 38239
# Processing document 38240
# Processing document 38241
# Processing document 38242
# Processing document 38243
# Processing document 38244
# Processing document 38245
# Processing document 38246
# Processing document 38247
# Processing document 38248
# Processing document 38249
# Processing document 38250
# Processing document 38251
# Processing document 38252
# Processing document 38255
# Processing document 38256
# Processing document 38257
# Processing document 38258
# Processing document 38259
# Processing document 38260
# Processing document 38261
# Processing document 38262
# Processing document 38263
# Processing document 38264
# Processing document 38265
# Processing document 38266
# Processing document 38267
# Processing document 38268
# Processing document 38269
# Processing document 38270
# Processing document 38271
# Processing document 38272
# Processing document 38273
# Processing document 38274
# Processing document 38275
# Processing document 38276
# Processing document 38277
# Processing document 38278
# Processing document 38279
# Processing document 38280
# Processing document 38281
# Processing document 38282
# Processing document 38283
# Processing document 38284
# Processing document 38285
# Processing document 38286
# Processing document 38287
# Processing document 38288
# Processing document 38289
# Processing document 38290
# Processing document 38291
# Processing document 38292
# Processing document 38293
# Processing document 38294
# Processing document 38295
# Processing document 38296
# Processing document 38297
# Processing document 38298
# Processing document 38299
# Processing document 38300
# Processing document 38301
# Processing document 38302
# Processing document 38303
# Processing document 38304
# Processing document 38305
# Processing document 38306
# Processing document 38307
# Processing document 38308
# Processing document 38309
# Processing document 38310
# Processing document 38311
# Processing document 38312
# Processing document 38313
# Processing document 38314
# Processing document 38315
# Processing document 38316
# Processing document 38317
# Processing document 38318
# Processing document 38319
# Processing document 38320
# Processing document 38321
# Processing document 38323
# Processing document 38324
# Processing document 38325
# Processing document 38326
# Processing document 38327
# Processing document 38328
# Processing document 38329
# Processing document 38330
# Processing document 38331
# Processing document 38332
# Processing document 38333
# Processing document 38334
# Processing document 38336
# Processing document 38337
# Processing document 38338
# Processing document 38339
# Processing document 38342
# Processing document 38343
# Processing document 38344
# Processing document 38346
# Processing document 38347
# Processing document 38348
# Processing document 38350
# Processing document 38351
# Processing document 38352
# Processing document 38353
# Processing document 38354
# Processing document 38355
# Processing document 38356
# Processing document 38357
# Processing document 38358
# Processing document 38359
# Processing document 38360
# Processing document 38361
# Processing document 38362
# Processing document 38363
# Processing document 38364
# Processing document 38365
# Processing document 38366
# Processing document 38367
# Processing document 38368
# Processing document 38369
# Processing document 38370
# Processing document 38371
# Processing document 38372
# Processing document 38373
# Processing document 38374
# Processing document 38375
# Processing document 38376
# Processing document 38377
# Processing document 38378
# Processing document 38379
# Processing document 38380
# Processing document 38381
# Processing document 38382
# Processing document 38383
# Processing document 38384
# Processing document 38385
# Processing document 38386
# Processing document 38387
# Processing document 38388
# Processing document 38389
# Processing document 38390
# Processing document 38391
# Processing document 38392
# Processing document 38393
# Processing document 38394
# Processing document 38395
# Processing document 38396
# Processing document 38397
# Processing document 38398
# Processing document 38399
# Processing document 38400
# Processing document 38401
# Processing document 38402
# Processing document 38403
# Processing document 38404
# Processing document 38405
# Processing document 38406
# Processing document 38407
# Processing document 38408
# Processing document 38409
# Processing document 38410
# Processing document 38411
# Processing document 38412
# Processing document 38413
# Processing document 38414
# Processing document 38415
# Processing document 38417
# Processing document 38418
# Processing document 38420
# Processing document 38421
# Processing document 38422
# Processing document 38423
# Processing document 38424
# Processing document 38425
# Processing document 38426
# Processing document 38427
# Processing document 38428
# Processing document 38429
# Processing document 38430
# Processing document 38431
# Processing document 38432
# Processing document 38433
# Processing document 38434
# Processing document 38435
# Processing document 38436
# Processing document 38437
# Processing document 38438
# Processing document 38439
# Processing document 38440
# Processing document 38441
# Processing document 38442
# Processing document 38443
# Processing document 38444
# Processing document 38445
# Processing document 38446
# Processing document 38447
# Processing document 38448
# Processing document 38449
# Processing document 38450
# Processing document 38452
# Processing document 38453
# Processing document 38454
# Processing document 38455
# Processing document 38456
# Processing document 38457
# Processing document 38458
# Processing document 38459
# Processing document 38460
# Processing document 38461
# Processing document 38462
# Processing document 38463
# Processing document 38464
# Processing document 38465
# Processing document 38466
# Processing document 38467
# Processing document 38468
# Processing document 38469
# Processing document 38470
# Processing document 38471
# Processing document 38472
# Processing document 38473
# Processing document 38474
# Processing document 38475
# Processing document 38476
# Processing document 38477
# Processing document 38478
# Processing document 38479
# Processing document 38480
# Processing document 38481
# Processing document 38482
# Processing document 38483
# Processing document 38484
# Processing document 38485
# Processing document 38486
# Processing document 38487
# Processing document 38488
# Processing document 38489
# Processing document 38490
# Processing document 38491
# Processing document 38492
# Processing document 38493
# Processing document 38494
# Processing document 38495
# Processing document 38496
# Processing document 38497
# Processing document 38498
# Processing document 38499
# Processing document 38500
# Processing document 38501
# Processing document 38502
# Processing document 38503
# Processing document 38504
# Processing document 38505
# Processing document 38507
# Processing document 38508
# Processing document 38509
# Processing document 38510
# Processing document 38511
# Processing document 38512
# Processing document 38513
# Processing document 38514
# Processing document 38515
# Processing document 38516
# Processing document 38517
# Processing document 38518
# Processing document 38519
# Processing document 38520
# Processing document 38521
# Processing document 38522
# Processing document 38523
# Processing document 38524
# Processing document 38525
# Processing document 38526
# Processing document 38527
# Processing document 38528
# Processing document 38529
# Processing document 38530
# Processing document 38531
# Processing document 38532
# Processing document 38533
# Processing document 38534
# Processing document 38535
# Processing document 38536
# Processing document 38537
# Processing document 38538
# Processing document 38539
# Processing document 38540
# Processing document 38541
# Processing document 38542
# Processing document 38545
# Processing document 38546
# Processing document 38547
# Processing document 38548
# Processing document 38549
# Processing document 38550
# Processing document 38551
# Processing document 38552
# Processing document 38553
# Processing document 38554
# Processing document 38555
# Processing document 38556
# Processing document 38557
# Processing document 38558
# Processing document 38559
# Processing document 38560
# Processing document 38561
# Processing document 38562
# Processing document 38563
# Processing document 38564
# Processing document 38565
# Processing document 38566
# Processing document 38567
# Processing document 38568
# Processing document 38569
# Processing document 38570
# Processing document 38571
# Processing document 38572
# Processing document 38573
# Processing document 38574
# Processing document 38575
# Processing document 38576
# Processing document 38577
# Processing document 38578
# Processing document 38579
# Processing document 38580
# Processing document 38581
# Processing document 38582
# Processing document 38583
# Processing document 38584
# Processing document 38585
# Processing document 38586
# Processing document 38587
# Processing document 38588
# Processing document 38590
# Processing document 38591
# Processing document 38592
# Processing document 38593
# Processing document 38594
# Processing document 38595
# Processing document 38596
# Processing document 38597
# Processing document 38598
# Processing document 38599
# Processing document 38600
# Processing document 38601
# Processing document 38602
# Processing document 38603
# Processing document 38604
# Processing document 38605
# Processing document 38606
# Processing document 38607
# Processing document 38608
# Processing document 38609
# Processing document 38610
# Processing document 38611
# Processing document 38612
# Processing document 38613
# Processing document 38614
# Processing document 38615
# Processing document 38616
# Processing document 38617
# Processing document 38618
# Processing document 38619
# Processing document 38620
# Processing document 38621
# Processing document 38622
# Processing document 38623
# Processing document 38624
# Processing document 38625
# Processing document 38626
# Processing document 38627
# Processing document 38628
# Processing document 38629
# Processing document 38630
# Processing document 38631
# Processing document 38632
# Processing document 38633
# Processing document 38634
# Processing document 38635
# Processing document 38636
# Processing document 38637
# Processing document 38638
# Processing document 38639
# Processing document 38640
# Processing document 38641
# Processing document 38642
# Processing document 38643
# Processing document 38644
# Processing document 38645
# Processing document 38646
# Processing document 38647
# Processing document 38648
# Processing document 38649
# Processing document 38650
# Processing document 38651
# Processing document 38652
# Processing document 38653
# Processing document 38654
# Processing document 38655
# Processing document 38656
# Processing document 38657
# Processing document 38658
# Processing document 38659
# Processing document 38660
# Processing document 38661
# Processing document 38662
# Processing document 38663
# Processing document 38664
# Processing document 38665
# Processing document 38666
# Processing document 38667
# Processing document 38668
# Processing document 38669
# Processing document 38670
# Processing document 38671
# Processing document 38672
# Processing document 38673
# Processing document 38674
# Processing document 38675
# Processing document 38676
# Processing document 38677
# Processing document 38678
# Processing document 38679
# Processing document 38680
# Processing document 38681
# Processing document 38682
# Processing document 38683
# Processing document 38684
# Processing document 38685
# Processing document 38686
# Processing document 38687
# Processing document 38688
# Processing document 38689
# Processing document 38690
# Processing document 38691
# Processing document 38692
# Processing document 38693
# Processing document 38694
# Processing document 38695
# Processing document 38696
# Processing document 38697
# Processing document 38698
# Processing document 38699
# Processing document 38700
# Processing document 38701
# Processing document 38702
# Processing document 38703
# Processing document 38704
# Processing document 38705
# Processing document 38706
# Processing document 38707
# Processing document 38708
# Processing document 38709
# Processing document 38710
# Processing document 38711
# Processing document 38712
# Processing document 38713
# Processing document 38714
# Processing document 38715
# Processing document 38716
# Processing document 38717
# Processing document 38718
# Processing document 38719
# Processing document 38720
# Processing document 38721
# Processing document 38722
# Processing document 38723
# Processing document 38724
# Processing document 38725
# Processing document 38726
# Processing document 38727
# Processing document 38729
# Processing document 38730
# Processing document 38731
# Processing document 38732
# Processing document 38733
# Processing document 38734
# Processing document 38735
# Processing document 38736
# Processing document 38737
# Processing document 38738
# Processing document 38739
# Processing document 38740
# Processing document 38741
# Processing document 38742
# Processing document 38743
# Processing document 38744
# Processing document 38745
# Processing document 38746
# Processing document 38747
# Processing document 38748
# Processing document 38749
# Processing document 38750
# Processing document 38751
# Processing document 38752
# Processing document 38753
# Processing document 38754
# Processing document 38755
# Processing document 38756
# Processing document 38757
# Processing document 38759
# Processing document 38760
# Processing document 38795
# Processing document 38805
# Processing document 38816
# Processing document 10000
# Processing document 10001
# Processing document 10002
# Processing document 10007
# Processing document 10008
# Processing document 10016
# Processing document 10017
# Processing document 10023
# Processing document 10025
# Processing document 10031
# Processing document 10042
# Processing document 10082
# Processing document 8514
# Processing document 9136
# Processing document 9137
# Processing document 9138
# Processing document 9139
# Processing document 9140
# Processing document 9141
# Processing document 9142
# Processing document 9143
# Processing document 9144
# Processing document 9145
# Processing document 9146
# Processing document 9147
# Processing document 9148
# Processing document 9149
# Processing document 9150
# Processing document 9151
# Processing document 9152
# Processing document 9153
# Processing document 9154
# Processing document 9155
# Processing document 9156
# Processing document 9157
# Processing document 9158
# Processing document 9159
# Processing document 9160
# Processing document 9161
# Processing document 9162
# Processing document 9163
# Processing document 9164
# Processing document 9165
# Processing document 9166
# Processing document 9167
# Processing document 9168
# Processing document 9169
# Processing document 9170
# Processing document 9171
# Processing document 9172
# Processing document 9173
# Processing document 9174
# Processing document 9175
# Processing document 9176
# Processing document 9450
# Processing document 9451
# Processing document 9452
# Processing document 9453
# Processing document 9454
# Processing document 9455
# Processing document 9456
# Processing document 9457
# Processing document 9458
# Processing document 9459
# Processing document 9460
# Processing document 9461
# Processing document 9462
# Processing document 9463
# Processing document 9464
# Processing document 9465
# Processing document 9466
# Processing document 9467
# Processing document 9468
# Processing document 9469
# Processing document 9470
# Processing document 9471
# Processing document 9472
# Processing document 9473
# Processing document 9474
# Processing document 9475
# Processing document 9476
# Processing document 9477
# Processing document 9478
# Processing document 9479
# Processing document 9480
# Processing document 9481
# Processing document 9482
# Processing document 9483
# Processing document 9484
# Processing document 9485
# Processing document 9486
# Processing document 9487
# Processing document 9488
# Processing document 9489
# Processing document 9490
# Processing document 9491
# Processing document 9492
# Processing document 9493
# Processing document 9494
# Processing document 9496
# Processing document 9497
# Processing document 9498
# Processing document 9500
# Processing document 9501
# Processing document 9502
# Processing document 9503
# Processing document 9504
# Processing document 9505
# Processing document 9506
# Processing document 9507
# Processing document 9509
# Processing document 9510
# Processing document 9511
# Processing document 9512
# Processing document 9513
# Processing document 9516
# Processing document 9517
# Processing document 9518
# Processing document 9519
# Processing document 9520
# Processing document 9521
# Processing document 9522
# Processing document 9523
# Processing document 9524
# Processing document 9525
# Processing document 9526
# Processing document 9527
# Processing document 9528
# Processing document 9529
# Processing document 9530
# Processing document 9531
# Processing document 9532
# Processing document 9533
# Processing document 9534
# Processing document 9535
# Processing document 9536
# Processing document 9537
# Processing document 9538
# Processing document 9539
# Processing document 9540
# Processing document 9541
# Processing document 9542
# Processing document 9543
# Processing document 9544
# Processing document 9545
# Processing document 9546
# Processing document 9547
# Processing document 9548
# Processing document 9549
# Processing document 9550
# Processing document 9551
# Processing document 9552
# Processing document 9553
# Processing document 9554
# Processing document 9555
# Processing document 9556
# Processing document 9557
# Processing document 9558
# Processing document 9559
# Processing document 9560
# Processing document 9561
# Processing document 9562
# Processing document 9563
# Processing document 9564
# Processing document 9565
# Processing document 9566
# Processing document 9567
# Processing document 9568
# Processing document 9569
# Processing document 9570
# Processing document 9571
# Processing document 9572
# Processing document 9573
# Processing document 9574
# Processing document 9575
# Processing document 9576
# Processing document 9577
# Processing document 9578
# Processing document 9579
# Processing document 9580
# Processing document 9581
# Processing document 9582
# Processing document 9583
# Processing document 9584
# Processing document 9585
# Processing document 9586
# Processing document 9587
# Processing document 9588
# Processing document 9589
# Processing document 9590
# Processing document 9591
# Processing document 9592
# Processing document 9593
# Processing document 9594
# Processing document 9595
# Processing document 9596
# Processing document 9597
# Processing document 9598
# Processing document 9599
# Processing document 9600
# Processing document 9601
# Processing document 9602
# Processing document 9603
# Processing document 9604
# Processing document 9605
# Processing document 9606
# Processing document 9607
# Processing document 9608
# Processing document 9609
# Processing document 9610
# Processing document 9611
# Processing document 9612
# Processing document 9613
# Processing document 9614
# Processing document 9615
# Processing document 9616
# Processing document 9617
# Processing document 9618
# Processing document 9619
# Processing document 9620
# Processing document 9621
# Processing document 9622
# Processing document 9623
# Processing document 9624
# Processing document 9625
# Processing document 9626
# Processing document 9627
# Processing document 9628
# Processing document 9629
# Processing document 9630
# Processing document 9631
# Processing document 9632
# Processing document 9633
# Processing document 9634
# Processing document 9635
# Processing document 9636
# Processing document 9637
# Processing document 9638
# Processing document 9639
# Processing document 9640
# Processing document 9641
# Processing document 9642
# Processing document 9643
# Processing document 9644
# Processing document 9645
# Processing document 9646
# Processing document 9647
# Processing document 9648
# Processing document 9649
# Processing document 9650
# Processing document 9651
# Processing document 9652
# Processing document 9653
# Processing document 9654
# Processing document 9655
# Processing document 9656
# Processing document 9657
# Processing document 9658
# Processing document 9659
# Processing document 9660
# Processing document 9661
# Processing document 9662
# Processing document 9663
# Processing document 9665
# Processing document 9666
# Processing document 9667
# Processing document 9668
# Processing document 9669
# Processing document 9670
# Processing document 9671
# Processing document 9672
# Processing document 9674
# Processing document 9675
# Processing document 9676
# Processing document 9678
# Processing document 9679
# Processing document 9680
# Processing document 9681
# Processing document 9682
# Processing document 9683
# Processing document 9684
# Processing document 9685
# Processing document 9686
# Processing document 9687
# Processing document 9688
# Processing document 9689
# Processing document 9690
# Processing document 9691
# Processing document 9692
# Processing document 9693
# Processing document 9694
# Processing document 9695
# Processing document 9696
# Processing document 9697
# Processing document 9698
# Processing document 9701
# Processing document 9702
# Processing document 9703
# Processing document 9704
# Processing document 9705
# Processing document 9706
# Processing document 9707
# Processing document 9708
# Processing document 9709
# Processing document 9711
# Processing document 9712
# Processing document 9713
# Processing document 9714
# Processing document 9715
# Processing document 9716
# Processing document 9717
# Processing document 9718
# Processing document 9719
# Processing document 9720
# Processing document 9721
# Processing document 9722
# Processing document 9724
# Processing document 9725
# Processing document 9726
# Processing document 9727
# Processing document 9728
# Processing document 9729
# Processing document 9730
# Processing document 9731
# Processing document 9732
# Processing document 9733
# Processing document 9734
# Processing document 9735
# Processing document 9736
# Processing document 9737
# Processing document 9738
# Processing document 9739
# Processing document 9740
# Processing document 9741
# Processing document 9742
# Processing document 9743
# Processing document 9744
# Processing document 9745
# Processing document 9746
# Processing document 9748
# Processing document 9749
# Processing document 9750
# Processing document 9751
# Processing document 9752
# Processing document 9753
# Processing document 9754
# Processing document 9755
# Processing document 9756
# Processing document 9757
# Processing document 9758
# Processing document 9759
# Processing document 9760
# Processing document 9761
# Processing document 9762
# Processing document 9763
# Processing document 9764
# Processing document 9765
# Processing document 9766
# Processing document 9767
# Processing document 9768
# Processing document 9769
# Processing document 9770
# Processing document 9771
# Processing document 9772
# Processing document 9773
# Processing document 9774
# Processing document 9775
# Processing document 9776
# Processing document 9777
# Processing document 9778
# Processing document 9779
# Processing document 9780
# Processing document 9781
# Processing document 9782
# Processing document 9783
# Processing document 9784
# Processing document 9785
# Processing document 9786
# Processing document 9787
# Processing document 9788
# Processing document 9789
# Processing document 9790
# Processing document 9791
# Processing document 9792
# Processing document 9793
# Processing document 9794
# Processing document 9795
# Processing document 9796
# Processing document 9797
# Processing document 9798
# Processing document 9799
# Processing document 9800
# Processing document 9801
# Processing document 9802
# Processing document 9803
# Processing document 9804
# Processing document 9805
# Processing document 9806
# Processing document 9807
# Processing document 9808
# Processing document 9809
# Processing document 9810
# Processing document 9811
# Processing document 9812
# Processing document 9813
# Processing document 9814
# Processing document 9815
# Processing document 9816
# Processing document 9817
# Processing document 9818
# Processing document 9819
# Processing document 9820
# Processing document 9821
# Processing document 9822
# Processing document 9823
# Processing document 9824
# Processing document 9825
# Processing document 9826
# Processing document 9827
# Processing document 9828
# Processing document 9829
# Processing document 9830
# Processing document 9831
# Processing document 9832
# Processing document 9833
# Processing document 9834
# Processing document 9835
# Processing document 9836
# Processing document 9837
# Processing document 9838
# Processing document 9839
# Processing document 9840
# Processing document 9841
# Processing document 9842
# Processing document 9843
# Processing document 9844
# Processing document 9845
# Processing document 9846
# Processing document 9847
# Processing document 9848
# Processing document 9849
# Processing document 9850
# Processing document 9851
# Processing document 9852
# Processing document 9853
# Processing document 9854
# Processing document 9855
# Processing document 9856
# Processing document 9857
# Processing document 9858
# Processing document 9859
# Processing document 9860
# Processing document 9861
# Processing document 9862
# Processing document 9863
# Processing document 9864
# Processing document 9865
# Processing document 9866
# Processing document 9867
# Processing document 9868
# Processing document 9869
# Processing document 9870
# Processing document 9871
# Processing document 9872
# Processing document 9873
# Processing document 9874
# Processing document 9875
# Processing document 9876
# Processing document 9877
# Processing document 9878
# Processing document 9879
# Processing document 9880
# Processing document 9881
# Processing document 9882
# Processing document 9883
# Processing document 9884
# Processing document 9885
# Processing document 9886
# Processing document 9887
# Processing document 9888
# Processing document 9889
# Processing document 9890
# Processing document 9891
# Processing document 9892
# Processing document 9893
# Processing document 9894
# Processing document 9895
# Processing document 9896
# Processing document 9897
# Processing document 9898
# Processing document 9899
# Processing document 9900
# Processing document 9901
# Processing document 9902
# Processing document 9903
# Processing document 9904
# Processing document 9905
# Processing document 9906
# Processing document 9907
# Processing document 9908
# Processing document 9909
# Processing document 9910
# Processing document 9911
# Processing document 9912
# Processing document 9913
# Processing document 9914
# Processing document 9915
# Processing document 9916
# Processing document 9917
# Processing document 9918
# Processing document 9919
# Processing document 9920
# Processing document 9921
# Processing document 9922
# Processing document 9923
# Processing document 9924
# Processing document 9925
# Processing document 9926
# Processing document 9927
# Processing document 9928
# Processing document 9929
# Processing document 9930
# Processing document 9931
# Processing document 9932
# Processing document 9933
# Processing document 9934
# Processing document 9935
# Processing document 9936
# Processing document 9937
# Processing document 9938
# Processing document 9939
# Processing document 9940
# Processing document 9941
# Processing document 9942
# Processing document 9943
# Processing document 9944
# Processing document 9945
# Processing document 9946
# Processing document 9947
# Processing document 9948
# Processing document 9949
# Processing document 9950
# Processing document 9951
# Processing document 9952
# Processing document 9953
# Processing document 9954
# Processing document 9955
# Processing document 9956
# Processing document 9957
# Processing document 9958
# Processing document 9959
# Processing document 9960
# Processing document 9961
# Processing document 9962
# Processing document 9963
# Processing document 9964
# Processing document 9965
# Processing document 9966
# Processing document 9967
# Processing document 9968
# Processing document 9969
# Processing document 9970
# Processing document 9971
# Processing document 9972
# Processing document 9973
# Processing document 9974
# Processing document 9975
# Processing document 9976
# Processing document 9977
# Processing document 9978
# Processing document 9979
# Processing document 9980
# Processing document 9981
# Processing document 9982
# Processing document 9983
# Processing document 9984
# Processing document 9985
# Processing document 9986
# Processing document 9987
# Processing document 9988
# Processing document 9989
# Processing document 9990
# Processing document 9991
# Processing document 9992
# Processing document 9993
# Processing document 9994
# Processing document 9995
# Processing document 9996
# Processing document 9997
# Processing document 9998
# Processing document 9999
# Processing document 58343
# Processing document 58826
# Processing document 58827
# Processing document 58828
# Processing document 58829
# Processing document 58830
# Processing document 58831
# Processing document 58832
# Processing document 58833
# Processing document 58835
# Processing document 58836
# Processing document 58837
# Processing document 58838
# Processing document 58839
# Processing document 58840
# Processing document 58841
# Processing document 58843
# Processing document 58860
# Processing document 58862
# Processing document 58902
# Processing document 58903
# Processing document 58904
# Processing document 58905
# Processing document 58906
# Processing document 58909
# Processing document 58910
# Processing document 58911
# Processing document 58912
# Processing document 58913
# Processing document 58914
# Processing document 58915
# Processing document 58916
# Processing document 58917
# Processing document 58918
# Processing document 58919
# Processing document 58920
# Processing document 58921
# Processing document 58922
# Processing document 58923
# Processing document 58924
# Processing document 58925
# Processing document 58926
# Processing document 58927
# Processing document 58966
# Processing document 58967
# Processing document 58968
# Processing document 58969
# Processing document 58970
# Processing document 58971
# Processing document 58972
# Processing document 58973
# Processing document 58974
# Processing document 58975
# Processing document 58976
# Processing document 58977
# Processing document 58978
# Processing document 58979
# Processing document 58980
# Processing document 58981
# Processing document 58982
# Processing document 58983
# Processing document 58984
# Processing document 58985
# Processing document 58986
# Processing document 58987
# Processing document 58988
# Processing document 58989
# Processing document 58990
# Processing document 58991
# Processing document 58992
# Processing document 58993
# Processing document 58994
# Processing document 58995
# Processing document 58996
# Processing document 58997
# Processing document 58998
# Processing document 58999
# Processing document 59000
# Processing document 59001
# Processing document 59002
# Processing document 59003
# Processing document 59004
# Processing document 60133
# Processing document 60134
# Processing document 60135
# Processing document 60136
# Processing document 60137
# Processing document 60138
# Processing document 60139
# Processing document 60140
# Processing document 60141
# Processing document 60142
# Processing document 60143
# Processing document 60144
# Processing document 60145
# Processing document 60146
# Processing document 60147
# Processing document 60148
# Processing document 60149
# Processing document 60150
# Processing document 60151
# Processing document 60152
# Processing document 60153
# Processing document 60154
# Processing document 60155
# Processing document 60156
# Processing document 60157
# Processing document 60158
# Processing document 60159
# Processing document 60160
# Processing document 60161
# Processing document 60162
# Processing document 60163
# Processing document 60164
# Processing document 60165
# Processing document 60166
# Processing document 60167
# Processing document 60168
# Processing document 60169
# Processing document 60170
# Processing document 60171
# Processing document 60172
# Processing document 60173
# Processing document 60174
# Processing document 60175
# Processing document 60176
# Processing document 60177
# Processing document 60178
# Processing document 60179
# Processing document 60180
# Processing document 60181
# Processing document 60182
# Processing document 60183
# Processing document 60184
# Processing document 60185
# Processing document 60186
# Processing document 60187
# Processing document 60188
# Processing document 60190
# Processing document 60191
# Processing document 60192
# Processing document 60193
# Processing document 60194
# Processing document 60195
# Processing document 60196
# Processing document 60197
# Processing document 60198
# Processing document 60199
# Processing document 60200
# Processing document 60201
# Processing document 60202
# Processing document 60203
# Processing document 60204
# Processing document 60205
# Processing document 60206
# Processing document 60207
# Processing document 60208
# Processing document 60209
# Processing document 60210
# Processing document 60211
# Processing document 60212
# Processing document 60213
# Processing document 60214
# Processing document 60215
# Processing document 60216
# Processing document 60217
# Processing document 60218
# Processing document 60219
# Processing document 60220
# Processing document 60221
# Processing document 60222
# Processing document 60223
# Processing document 60224
# Processing document 60225
# Processing document 60226
# Processing document 60227
# Processing document 60228
# Processing document 60229
# Processing document 60230
# Processing document 60231
# Processing document 60232
# Processing document 60233
# Processing document 60234
# Processing document 60235
# Processing document 60236
# Processing document 60237
# Processing document 60238
# Processing document 60239
# Processing document 60240
# Processing document 60241
# Processing document 60242
# Processing document 60243
# Processing document 60244
# Processing document 60245
# Processing document 60246
# Processing document 60247
# Processing document 60248
# Processing document 60249
# Processing document 60251
# Processing document 60252
# Processing document 60253
# Processing document 60254
# Processing document 60255
# Processing document 60256
# Processing document 60258
# Processing document 60259
# Processing document 60261
# Processing document 60262
# Processing document 60263
# Processing document 60264
# Processing document 60265
# Processing document 60266
# Processing document 60267
# ...
# Processing document 77382
# Processing document 77383
# Processing document 77384
# Processing document 77385
# Processing document 77386
# Processing document 77387
# Processing document 77388
# Processing document 77389
# Processing document 77390
# Processing document 77391
# Processing document 77392
# Processing document 77393
# Processing document 77394
# Processing document 77395
# Processing document 77396
# Processing document 77397
# Processing document 77398
# Processing document 77399
# Processing document 77400
# Processing document 77401
# Processing document 77803
# Processing document 77804
# Processing document 77805
# Processing document 77806
# Processing document 77807
# Processing document 77808
# Processing document 77809
# Processing document 77810
# Processing document 77811
# Processing document 77812
# Processing document 77813
# Processing document 77814
# Processing document 77815
# Processing document 77816
# Processing document 77817
# Processing document 77818
# Processing document 77819
# Processing document 77820
# Processing document 77821
# Processing document 77822
# Processing document 77823
# Processing document 77850
# Processing document 178474
# Processing document 178475
# Processing document 178476
# Processing document 178599
# Processing document 178600
# Processing document 178603
# Processing document 178604
# Processing document 178605
# Processing document 178606
# Processing document 178607
# Processing document 178608
# Processing document 178609
# Processing document 178610
# Processing document 178611
# Processing document 178612
# Processing document 178614
# Processing document 178615
# Processing document 178617
# Processing document 178618
# Processing document 178619
# Processing document 178620
# Processing document 178621
# Processing document 178623
# Processing document 178624
# Processing document 178625
# Processing document 178626
# Processing document 178627
# Processing document 178628
# Processing document 178629
# Processing document 178631
# Processing document 178632
# Processing document 178633
# Processing document 178634
# Processing document 178635
# Processing document 178636
# Processing document 178638
# Processing document 178639
# Processing document 178640
# Processing document 178641
# Processing document 178643
# Processing document 178644
# Processing document 178645
# Processing document 178646
# Processing document 178647
# Processing document 178648
# Processing document 178649
# Processing document 178650
# Processing document 178651
# Processing document 178653
# Processing document 178654
# Processing document 178655
# Processing document 178656
# Processing document 178658
# Processing document 178659
# Processing document 178661
# Processing document 178663
# Processing document 178664
# Processing document 178665
# Processing document 178667
# Processing document 178668
# Processing document 178669
# Processing document 178670
# Processing document 178671
# Processing document 178672
# Processing document 178673
# Processing document 178675
# Processing document 178676
# Processing document 178677
# Processing document 178679
# Processing document 178680
# Processing document 178681
# Processing document 178682
# Processing document 178683
# Processing document 178696
# Processing document 178697
# Processing document 178699
# Processing document 178700
# Processing document 178701
# Processing document 178702
# Processing document 178703
# Processing document 178704
# Processing document 178706
# Processing document 178707
# Processing document 178708
# Processing document 178709
# Processing document 178710
# Processing document 178711
# Processing document 178712
# Processing document 178713
# Processing document 178714
# Processing document 178716
# Processing document 178717
# Processing document 178718
# Processing document 178719
# Processing document 178721
# Processing document 178722
# Processing document 178723
# Processing document 178724
# Processing document 178725
# Processing document 178729
# Processing document 178730
# Processing document 178731
# Processing document 178732
# Processing document 178733
# Processing document 178734
# Processing document 178735
# Processing document 178736
# Processing document 178740
# Processing document 178741
# Processing document 178742
# Processing document 178743
# Processing document 178746
# Processing document 178747
# Processing document 178748
# Processing document 178749
# Processing document 178752
# Processing document 178753
# Processing document 178755
# Processing document 178756
# Processing document 178757
# Processing document 178762
# Processing document 178763
# Processing document 178764
# Processing document 178766
# Processing document 178767
# Processing document 178768
# Processing document 178769
# Processing document 178770
# Processing document 178771
# Processing document 178772
# Processing document 178774
# Processing document 178775
# Processing document 178776
# Processing document 178778
# Processing document 178779
# Processing document 178780
# Processing document 178781
# Processing document 178782
# Processing document 178784
# Processing document 178786
# Processing document 178788
# Processing document 178789
# Processing document 178790
# Processing document 178791
# Processing document 178793
# Processing document 178794
# Processing document 178795
# Processing document 178796
# Processing document 178799
# Processing document 178802
# Processing document 178809
# Processing document 178810
# Processing document 178812
# Processing document 178817
# Processing document 178857
# Processing document 178859
# Processing document 178860
# Processing document 178861
# Processing document 178862
# Processing document 178863
# Processing document 178866
# Processing document 178867
# Processing document 178868
# Processing document 178869
# Processing document 178870
# Processing document 178871
# Processing document 178872
# Processing document 178873
# Processing document 178876
# Processing document 178877
# Processing document 178878
# Processing document 178880
# Processing document 178881
# Processing document 178882
# Processing document 178883
# Processing document 178884
# Processing document 178885
# Processing document 178886
# Processing document 178887
# Processing document 178888
# Processing document 178893
# Processing document 178894
# Processing document 178895
# Processing document 178896
# Processing document 178897
# Processing document 178898
# Processing document 178899
# Processing document 178900
# Processing document 178901
# Processing document 178902
# Processing document 178903
# Processing document 178904
# Processing document 178905
# Processing document 178906
# Processing document 178907
# Processing document 178908
# Processing document 178909
# Processing document 178910
# Processing document 178911
# Processing document 178912
# Processing document 178913
# Processing document 178914
# Processing document 178915
# Processing document 178916
# Processing document 178917
# Processing document 178919
# Processing document 178920
# Processing document 178926
# Processing document 178928
# Processing document 178929
# Processing document 178930
# Processing document 178932
# Processing document 178933
# Processing document 178934
# Processing document 178980
# Processing document 178981
# Processing document 178982
# Processing document 178983
# Processing document 178984
# Processing document 178986
# Processing document 178987
# Processing document 178988
# Processing document 178989
# Processing document 178990
# Processing document 178991
# Processing document 178992
# Processing document 178994
# Processing document 178998
# Processing document 179000
# Processing document 179001
# Processing document 179003
# Processing document 179005
# Processing document 179006
# Processing document 179007
# Processing document 179008
# Processing document 179009
# Processing document 179011
# Processing document 179013
# Processing document 179015
# Processing document 179016
# Processing document 179025
# Processing document 179026
# Processing document 179027
# Processing document 179028
# Processing document 179029
# Processing document 179030
# Processing document 179031
# Processing document 179033
# Processing document 179034
# Processing document 179035
# Processing document 179036
# Processing document 179037
# Processing document 179038
# Processing document 179039
# Processing document 179041
# Processing document 179042
# Processing document 179043
# Processing document 179044
# Processing document 179046
# Processing document 179047
# Processing document 179048
# Processing document 179049
# Processing document 179050
# Processing document 179051
# Processing document 179053
# Processing document 179054
# Processing document 179055
# Processing document 179056
# Processing document 179058
# Processing document 179060
# Processing document 179062
# Processing document 179063
# Processing document 179066
# Processing document 179067
# Processing document 179068
# Processing document 179069
# Processing document 179070
# Processing document 179071
# Processing document 179073
# Processing document 179075
# Processing document 179076
# Processing document 179083
# Processing document 179084
# Processing document 179085
# Processing document 179086
# Processing document 179087
# Processing document 179088
# Processing document 179089
# Processing document 179091
# Processing document 179092
# Processing document 179093
# Processing document 179094
# Processing document 179095
# Processing document 179097
# Processing document 179098
# Processing document 179099
# Processing document 179102
# Processing document 179103
# Processing document 179105
# Processing document 179106
# Processing document 179107
# Processing document 179108
# Processing document 179109
# Processing document 179110
# Processing document 179111
# Processing document 179112
# Processing document 179113
# Processing document 179114
# Processing document 179115
# Processing document 179116
# Processing document 83876
# Processing document 83905
# Processing document 83907
# Processing document 83910
# Processing document 83911
# Processing document 83913
# Processing document 83915
# Processing document 83918
# Processing document 83919
# Processing document 83922
# Processing document 83931
# Processing document 83937
# Processing document 83943
# Processing document 83944
# Processing document 83967
# Processing document 83968
# Processing document 83971
# Processing document 83972
# Processing document 83976
# Processing document 83977
# Processing document 83978
# Processing document 83979
# Processing document 83980
# Processing document 83983
# Processing document 83992
# Processing document 84007
# Processing document 84015
# Processing document 84018
# Processing document 84019
# Processing document 84020
# Processing document 84022
# Processing document 84024
# Processing document 84053
# Processing document 84057
# Processing document 84058
# Processing document 84059
# Processing document 84060
# Processing document 84061
# Processing document 84062
# Processing document 84063
# Processing document 84064
# Processing document 84065
# Processing document 84066
# Processing document 84069
# Processing document 84075
# Processing document 84077
# Processing document 84078
# Processing document 84079
# Processing document 84080
# Processing document 84082
# Processing document 84083
# Processing document 84084
# Processing document 84085
# Processing document 84091
# Processing document 84092
# Processing document 84096
# Processing document 84097
# Processing document 84098
# Processing document 84099
# Processing document 84100
# Processing document 84121
# Processing document 84127
# Processing document 84128
# Processing document 84129
# Processing document 84133
# Processing document 84135
# Processing document 84136
# Processing document 84137
# Processing document 84138
# Processing document 84139
# Processing document 84140
# Processing document 84141
# Processing document 84145
# Processing document 84156
# Processing document 84159
# Processing document 84169
# Processing document 84178
# Processing document 84182
# Processing document 84189
# Processing document 84192
# Processing document 84193
# Processing document 84194
# Processing document 84204
# Processing document 84205
# Processing document 84206
# Processing document 84207
# Processing document 84208
# Processing document 84209
# Processing document 84210
# Processing document 84211
# Processing document 84212
# Processing document 84213
# Processing document 84214
# Processing document 84215
# Processing document 84216
# Processing document 84217
# Processing document 84218
# Processing document 84219
# Processing document 84220
# Processing document 84221
# Processing document 84222
# Processing document 84223
# Processing document 84224
# Processing document 84225
# Processing document 84228
# Processing document 84231
# Processing document 84232
# Processing document 84233
# Processing document 84234
# Processing document 84235
# Processing document 84236
# Processing document 84237
# Processing document 84238
# Processing document 84239
# Processing document 84240
# Processing document 84241
# Processing document 84242
# Processing document 84243
# Processing document 84244
# Processing document 84245
# Processing document 84246
# Processing document 84247
# Processing document 84248
# Processing document 84249
# Processing document 84250
# Processing document 84251
# Processing document 84252
# Processing document 84253
# Processing document 84254
# Processing document 84258
# Processing document 84259
# Processing document 84260
# Processing document 84261
# Processing document 84262
# Processing document 84264
# Processing document 84265
# Processing document 84266
# Processing document 84267
# Processing document 84269
# Processing document 84270
# Processing document 84271
# Processing document 84272
# Processing document 84273
# Processing document 84274
# Processing document 84275
# Processing document 84276
# Processing document 84277
# Processing document 84278
# Processing document 84279
# Processing document 84280
# Processing document 84281
# Processing document 84282
# Processing document 84283
# Processing document 84284
# Processing document 84285
# Processing document 84286
# Processing document 84288
# Processing document 84289
# Processing document 84290
# Processing document 84291
# Processing document 84292
# Processing document 84293
# Processing document 84294
# Processing document 84295
# Processing document 84296
# Processing document 84297
# Processing document 84298
# Processing document 84299
# Processing document 84300
# Processing document 84301
# Processing document 84302
# Processing document 84303
# Processing document 84304
# Processing document 84305
# Processing document 84306
# Processing document 84307
# Processing document 84310
# Processing document 84311
# Processing document 84312
# Processing document 84313
# Processing document 84314
# Processing document 84315
# Processing document 84316
# Processing document 84319
# Processing document 84320
# Processing document 84321
# Processing document 84329
# Processing document 84331
# Processing document 84332
# Processing document 84334
# Processing document 84338
# Processing document 84339
# Processing document 84340
# Processing document 84341
# Processing document 84342
# Processing document 84343
# Processing document 84344
# Processing document 84345
# Processing document 84346
# Processing document 84347
# Processing document 84348
# Processing document 84349
# Processing document 84350
# Processing document 84351
# Processing document 84352
# Processing document 84353
# Processing document 84354
# Processing document 84380
# Processing document 84395
# Processing document 84401
# Processing document 84414
# Processing document 84423
# Processing document 84428
# Processing document 84429
# Processing document 84430
# Processing document 84433
# Processing document 84434
# Processing document 84435
# Processing document 84436
# Processing document 84437
# Processing document 84438
# Processing document 84439
# Processing document 84440
# Processing document 84441
# Processing document 84442
# Processing document 84447
# Processing document 84448
# Processing document 84449
# Processing document 84450
# Processing document 84451
# Processing document 84452
# Processing document 84506
# Processing document 84508
# Processing document 84509
# Processing document 84510
# Processing document 84511
# Processing document 84538
# Processing document 84552
# Processing document 84553
# Processing document 84554
# Processing document 84555
# Processing document 84557
# Processing document 84559
# Processing document 84560
# Processing document 84562
# Processing document 84563
# Processing document 84564
# Processing document 84565
# Processing document 84568
# Processing document 84569
# Processing document 84570
